# %%
# 라이브러리 불러오기
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %config InlineBackend.figure_format='retina'
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import warnings
warnings.filterwarnings('ignore')
import sys
import scipy.stats as spst
import matplotlib.ticker as mtick

# 시각화, 한글폰트 설정
plt.rc('font', family='AppleGothic')
sns.set(font="AppleGothic",             # "NanumGothicCoding", 
        rc={"axes.unicode_minus":False},  # 마이너스 부호 깨짐 현상 해결
        style='darkgrid')
# Out:
# /Users/song-yuojin/opt/anaconda3/lib/python3.8/site-packages/scipy/__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
data = pd.read_csv('전통시장 역세권.csv')
data
# Out:
#                        ID        MRKT_NM CTPRVN_NM SIGNGU_NM  LEGALDONG_CD  \
# 0     KC603PO22N000000001           강남시장        서울       강남구    1168010700
# 1     KC603PO22N000000002           신사상가        서울       강남구    1168011000
# 2     KC603PO22N000000003         영동전통시장        서울       강남구    1168010800
# 3     KC603PO22N000000004         청담삼익시장        서울       강남구    1168010400
# 4     KC603PO22N000000005       고분다리전통시장        서울       강동구    1174010900
# ...                   ...            ...       ...       ...           ...
# 1396  KC603PO22N000001397         마천전통시장        경남       함양군    4887031021
# 1397  KC603PO22N000001398        영등포유통상가        서울      영등포구    1156011200
# 1398  KC603PO22N000001399         고려쇼핑센터        부산       사상구    2653010400
# 1399  KC603PO22N000001400  부산광역시철강판매협동조합        부산       사상구    2653010800
# 1400  KC603PO22N000001401        Team204        서울        중구    1114016200
#
#      LEGALDONG_NM   ADSTRD_CD ADSTRD_NM    RDNMADR_CD              RDNMADR_NM  \
# 0             신사동  1168051000       신사동  1.168040e+11        서울 강남구 압구정로2길 46
# 1            압구정동  1168054500      압구정동  1.168040e+11     서울 강남구 압구정로29길 72-1
# 2             논현동  1168052100      논현1동  1.168040e+11      서울 강남구 강남대로128길 20
# 3             청담동  1168056500       청담동  1.168040e+11       서울 강남구 학동로101길 26
# 4             천호동  1174060000      천호1동  1.174040e+11       서울 강동구 구천면로34길 13
# ...           ...         ...       ...           ...                     ...
# 1396      마천면 가흥리  4887031000       마천면  4.519030e+11  경남 함양군 마천면 천왕봉로 1144-2
# 1397        당산동2가  1156055000      당산1동  1.156030e+11        서울 영등포구 영등포로 109
# 1398          괘법동  2653062000       괘법동  2.632030e+11          부산 사상구 사상로 208
# 1399          엄궁동  2653068000       엄궁동  2.653040e+11  부산 사상구 강변대로532번길 17-26
# 1400          신당동  1114061500       신당동  1.114030e+11            서울 중구 마장로 30
#
#       ...  TOILET_EXST_AT PRKPLCE_EXST_AT  OPNNG_YEAR        TEL_NO POPLTN_CO  \
# 0     ...               Y               Y        1974           NaN  490424.0
# 1     ...               Y               N        1976           NaN  490424.0
# 2     ...               Y               Y        2011           NaN  490424.0
# 3     ...               Y               Y        1980           NaN  490424.0
# 4     ...               Y               Y        2011  02-6227-0045  374106.0
# ...   ...             ...             ...         ...           ...       ...
# 1396  ...               Y               Y        1987           NaN   28588.0
# 1397  ...               Y               Y        1999  02-2635-7300  408384.0
# 1398  ...               Y               Y        1985           NaN  183547.0
# 1399  ...               N               N        1997           NaN  183547.0
# 1400  ...               Y               Y        2019           NaN  138972.0
#
#      SIGNGU_MRKT_CO  SIGNGU_STORE_CO FCLTY_POPLTN_CO  \
# 0                 4              453          1082.0
# 1                 4              453          1082.0
# 2                 4              453          1082.0
# 3                 4              453          1082.0
# 4                 6              682           548.0
# ...             ...              ...             ...
# 1396              4              195           146.0
# 1397              8             1951           209.0
# 1398             18             6251            29.0
# 1399             18             6251            29.0
# 1400             25            21486             6.0
#
#                                     FILE_NM   BASE_DE
# 0     KC_603_TRD_MART_CTL_STATN_BIZAEA_2022  20220706
# 1     KC_603_TRD_MART_CTL_STATN_BIZAEA_2022  20220706
# 2     KC_603_TRD_MART_CTL_STATN_BIZAEA_2022  20220706
# 3     KC_603_TRD_MART_CTL_STATN_BIZAEA_2022  20220706
# 4     KC_603_TRD_MART_CTL_STATN_BIZAEA_2022  20220706
# ...                                     ...       ...
# 1396  KC_603_TRD_MART_CTL_STATN_BIZAEA_2022  20220706
# 1397  KC_603_TRD_MART_CTL_STATN_BIZAEA_2022  20220706
# 1398  KC_603_TRD_MART_CTL_STATN_BIZAEA_2022  20220706
# 1399  KC_603_TRD_MART_CTL_STATN_BIZAEA_2022  20220706
# 1400  KC_603_TRD_MART_CTL_STATN_BIZAEA_2022  20220706
#
# [1401 rows x 30 columns]

# %%
data['']
