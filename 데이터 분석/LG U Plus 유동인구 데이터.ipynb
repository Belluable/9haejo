# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('유동인구.csv')
df
# Out:
#       BASE_DE       GID_ID      GID_LO     GID_LA  CTPRVN_CD CTPRVN_NM  \
# 0    20201105   83,558,707  127.062706  37.066059         41       경기도
# 1    20201105   83,912,334  127.070854  37.809269         41       경기도
# 2    20201105   83,912,334  127.070854  37.809269         41       경기도
# 3    20201105   83,559,754  127.059967  37.537926         11     서울특별시
# 4    20201105   70,904,337  126.613441  37.441681         28     인천광역시
# ..        ...          ...         ...        ...        ...       ...
# 595  20201101   76,215,741  126.802185  37.323963         41       경기도
# 596  20201101  135,845,082  128.914429  37.798855         42       강원도
# 597  20201101  143,363,831  129.173355  37.443523         42       강원도
# 598  20201101   84,136,186  127.079155  37.748909         41       경기도
# 599  20201101   94,244,397  127.439003  36.326729         30     대전광역시
#
#      SIGNGU_CD SIGNGU_NM  ADSTRD_CD ADSTRD_NM WKDAY_NM  MVMN_TIME  \
# ...

# %%
#보행자 인구수
# AGRDE_CO 연령대

# %%
# GID_ID, GID_LO, GID_LA, CTPRVN_NM, PDSTRN_POPLTN_CO, PDSTRN_ELSE_POPLTN_CO, AGRDE_CO

# %%
df.isnull().sum()
# Out:
# BASE_DE                  0
# GID_ID                   0
# GID_LO                   0
# GID_LA                   0
# CTPRVN_CD                0
# CTPRVN_NM                0
# SIGNGU_CD                0
# SIGNGU_NM                0
# ADSTRD_CD                0
# ADSTRD_NM                0
# WKDAY_NM                 0
# MVMN_TIME                0
# SEXDSTN_FLAG_CD          0
# AGRDE_CO                 0
# PDSTRN_POPLTN_CO         0
# PDSTRN_ELSE_POPLTN_CO    0
# dtype: int64

# %%
df['CTPRVN_NM'].value_counts()
# Out:
# 서울특별시      236
# 경기도        178
# 인천광역시       83
# 강원도         29
# 전라남도        18
# 부산광역시       17
# 대구광역시       11
# 경상남도         6
# 대전광역시        4
# 충청남도         3
# 제주특별자치도      3
# 광주광역시        3
# 울산광역시        2
# 전라북도         2
# 충청북도         2
# 세종특별자치시      2
# 경상북도         1
# Name: CTPRVN_NM, dtype: int64

# %%
# 서울시 유동 인구 데이터가 가장 많음

# %%
df['AGRDE_CO'].value_counts()
# Out:
# 4    123
# 5    115
# 1     97
# 3     83
# 6     69
# 2     65
# 7     46
# 0      2
# Name: AGRDE_CO, dtype: int64

# %%
# 연령대 별 :

# %%
sns.countplot(df['AGRDE_CO'])
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='AGRDE_CO', ylabel='count'>

# %%
# 고령자 분들이 많다.

# %% [markdown]
# ## 필요없는 데이터 열 제거

# %%
df = df.drop(['BASE_DE','SIGNGU_CD', 'ADSTRD_NM', 'MVMN_TIME', 'SEXDSTN_FLAG_CD'], axis=1)
df
# Out:
#           GID_ID      GID_LO     GID_LA  CTPRVN_CD CTPRVN_NM SIGNGU_NM  \
# 0     83,558,707  127.062706  37.066059         41       경기도       평택시
# 1     83,912,334  127.070854  37.809269         41       경기도       양주시
# 2     83,912,334  127.070854  37.809269         41       경기도       양주시
# 3     83,559,754  127.059967  37.537926         11     서울특별시       성동구
# 4     70,904,337  126.613441  37.441681         28     인천광역시        중구
# ..           ...         ...        ...        ...       ...       ...
# 595   76,215,741  126.802185  37.323963         41       경기도       안산시
# 596  135,845,082  128.914429  37.798855         42       강원도       강릉시
# 597  143,363,831  129.173355  37.443523         42       강원도       삼척시
# 598   84,136,186  127.079155  37.748909         41       경기도      의정부시
# 599   94,244,397  127.439003  36.326729         30     대전광역시        동구
#
#      ADSTRD_CD WKDAY_NM  AGRDE_CO  PDSTRN_POPLTN_CO  PDSTRN_ELSE_POPLTN_CO
# ...

# %%
df = df.drop('WKDAY_NM', axis=1)

# %%
df
# Out:
#           GID_ID      GID_LO     GID_LA  CTPRVN_CD CTPRVN_NM SIGNGU_NM  \
# 0     83,558,707  127.062706  37.066059         41       경기도       평택시
# 1     83,912,334  127.070854  37.809269         41       경기도       양주시
# 2     83,912,334  127.070854  37.809269         41       경기도       양주시
# 3     83,559,754  127.059967  37.537926         11     서울특별시       성동구
# 4     70,904,337  126.613441  37.441681         28     인천광역시        중구
# ..           ...         ...        ...        ...       ...       ...
# 595   76,215,741  126.802185  37.323963         41       경기도       안산시
# 596  135,845,082  128.914429  37.798855         42       강원도       강릉시
# 597  143,363,831  129.173355  37.443523         42       강원도       삼척시
# 598   84,136,186  127.079155  37.748909         41       경기도      의정부시
# 599   94,244,397  127.439003  36.326729         30     대전광역시        동구
#
#      ADSTRD_CD  AGRDE_CO  PDSTRN_POPLTN_CO  PDSTRN_ELSE_POPLTN_CO
# ...

# %% [markdown]
# ## 열 이름 변경

# %%
df = df.rename(columns={'GID_ID' :  '격자ID'})
df
# Out:
#             격자ID      GID_LO     GID_LA  CTPRVN_CD CTPRVN_NM SIGNGU_NM  \
# 0     83,558,707  127.062706  37.066059         41       경기도       평택시
# 1     83,912,334  127.070854  37.809269         41       경기도       양주시
# 2     83,912,334  127.070854  37.809269         41       경기도       양주시
# 3     83,559,754  127.059967  37.537926         11     서울특별시       성동구
# 4     70,904,337  126.613441  37.441681         28     인천광역시        중구
# ..           ...         ...        ...        ...       ...       ...
# 595   76,215,741  126.802185  37.323963         41       경기도       안산시
# 596  135,845,082  128.914429  37.798855         42       강원도       강릉시
# 597  143,363,831  129.173355  37.443523         42       강원도       삼척시
# 598   84,136,186  127.079155  37.748909         41       경기도      의정부시
# 599   94,244,397  127.439003  36.326729         30     대전광역시        동구
#
#      ADSTRD_CD  AGRDE_CO  PDSTRN_POPLTN_CO  PDSTRN_ELSE_POPLTN_CO
# ...

# %%
df = df.rename(columns={'PDSTRN_POPLTN_CO' :  '보행자 수'})
df
# Out:
#             격자ID      GID_LO     GID_LA  CTPRVN_CD CTPRVN_NM SIGNGU_NM  \
# 0     83,558,707  127.062706  37.066059         41       경기도       평택시
# 1     83,912,334  127.070854  37.809269         41       경기도       양주시
# 2     83,912,334  127.070854  37.809269         41       경기도       양주시
# 3     83,559,754  127.059967  37.537926         11     서울특별시       성동구
# 4     70,904,337  126.613441  37.441681         28     인천광역시        중구
# ..           ...         ...        ...        ...       ...       ...
# 595   76,215,741  126.802185  37.323963         41       경기도       안산시
# 596  135,845,082  128.914429  37.798855         42       강원도       강릉시
# 597  143,363,831  129.173355  37.443523         42       강원도       삼척시
# 598   84,136,186  127.079155  37.748909         41       경기도      의정부시
# 599   94,244,397  127.439003  36.326729         30     대전광역시        동구
#
#      ADSTRD_CD  AGRDE_CO  보행자 수  PDSTRN_ELSE_POPLTN_CO
# 0     41220520         6     10                      4
# ...
